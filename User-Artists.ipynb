# %% [markdown]
# # User-Artists
#
# <b>TASK:</b> Given User requirements (Artist Category, Type of Event, Budget, Location and Gathering Size) predict type of <i>Artists</i> that would be pitched to the Users to capture their requirements accurately.
#
# In this Notebook I have attempted to GET Similar Users based on his/her requirements.<br>
# <i>Method Used:</i> TF-IDF (Term Frequency - Inverse Document Frequency) on Category, Event and Location of the Event

# %% [markdown]
# ## Library

# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %% [markdown]
# ### Dataset
# The Dataset is provided by [StarClinch](https://starclinch.com).
#
# Information about the given Dataset:
#
# <i><b>asid:</b></i>ID of the ROW<br>
# <i><b>created:</b></i>Date + Time of the creation.<br>
#
# <i><b>dealid:</b></i>(Unique) ID of the DEAL <br>
# <i><b>dealowner:</b></i> Name of the Person the deal is assigned to <br>
#
# <i><b>clientname:</b></i>Name of the User (client) <br>
# <i><b>location:</b></i>Location of the EVENT <br>
# <i><b>categoryname:</b></i>Artists Category. (14 Distinct Categories)<br>
# <i><b>eventname:</b></i>Type of Event. (14 Distinct Event Types)<br>
# <i><b>budget:</b></i>Budget for the Event given by User.<br>
# <i><b>gathering:</b></i>Gathering Size<br>
# <i><b>date:</b></i>Event Date<br>
#
# <i><b>artistsurls:</b></i>URLS of the artists pitched to the User<br>
# <i><b>artists:</b></i>ID of the artists pitched<br>
#
# <i><b>lookingfor</b></i> is mostly empty as it signifies whether the user have already specified which artists he/she |wants in the event.<br>
# <i><b>city:</b></i>Value is extracted from location<br>
#
# For List of Artist Categories and Type of Events visit [StarClinch](https://starclinch.com/requirement.html)

# %%
# Read the Dataset
df = pd.read_csv('artist-pitch.csv')
df.head()
# Out:
#    asid          created  dealid                  dealowner  \
# 0   272  5/17/2018 22:02    3255  Shambhavi from StarClinch
# 1   338  5/22/2018 16:43    4995    Shalini from StarClinch
# 2   300  5/19/2018 20:03    5814  Shambhavi from StarClinch
# 3   268  5/17/2018 17:26    5871   Prasanta From StarClinch
# 4   320  5/21/2018 19:19    6395    Nitisha from StarClinch
#
#             clientname                                  location  \
# 0                 Amit                Nagpur, Maharashtra, India
# 1               Kavita  Andheri East, Mumbai, Maharashtra, India
# 2        Gautam Kapoor                               Jim corbett
# 3       Rajat Aggarwal             Beauty & Spa, praghati maidan
# 4  Ajay Kumar   dhiman                                Chandigarh
#
#          categoryname   eventname  \
# 0              SINGER     charity
# 1        ANCHOR/EMCEE   corporate
# 2           LIVE BAND     wedding
# 3        ANCHOR/EMCEE  exhibition
# 4  PHOTO/VIDEOGRAPHER     wedding
#
#                                           artisturls  \
# 0  abhigyan-das, deepak-malik, mohit-gaur, pawand...
# 1  divya-malik, saddvi-bajaj, vandana-bisht, aish...
# 2  anhad-the-band, rangreza-the-band, big-m, mera...
# 3  anchor-ekta-sharma, anchor-shina-gujral, kanis...
# 4  aj-frames, soulmate-weddings, vivah-moments, s...
#
#                                              artists  budget  gathering  \
# 0  15,90,50,15,90,53,15,70,00,00,00,00,00,00,00,0...  200000     2000.0
# 1  40,41,30,64,09,72,93,40,00,00,00,00,00,00,00,0...   85000     1000.0
# 2            33,29,25,19,72,41,44,30,00,00,00,00,000   30000      160.0
# 3  2,43,65,02,72,02,40,56,00,00,00,00,00,00,00,00...   10000     2000.0
# 4  2,39,37,22,63,29,34,12,00,00,00,00,00,00,00,00...  150000      250.0
#
#          date                    lookingfor        city
# 0  16-06-2018                           NaN         NaN
# 1  16-11-2018                           NaN       Delhi
# 2  08-02-2019                           NaN       Delhi
# 3  28-05-2018   https://starclinch.com/ilia       Delhi
# 4  10-11-2018  Harnav Bir Singh Photography  Chandigarh

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 15 columns):
# asid            81 non-null int64
# created         81 non-null object
# dealid          81 non-null int64
# dealowner       81 non-null object
# clientname      81 non-null object
# location        81 non-null object
# categoryname    81 non-null object
# eventname       81 non-null object
# artisturls      81 non-null object
# artists         81 non-null object
# budget          81 non-null int64
# gathering       80 non-null float64
# date            81 non-null object
# lookingfor      13 non-null object
# city            48 non-null object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 9.6+ KB

# %% [markdown]
# ``` Gathering have 1 missing value ```

# %%
df[df['gathering'].isnull()]
# Out:
#     asid          created  dealid  dealowner        clientname location  \
# 79   387  5/25/2018 17:50    6814  Shambhavi  Anshika Bhatelay     Agra
#
#    categoryname  eventname                                         artisturls  \
# 79    LIVE BAND  corporate  delhicious-harmony, ahad-band, medlon, soulful...
#
#                                               artists  budget  gathering  \
# 79  2,40,55,32,33,91,62,43,00,00,00,00,00,00,00,00...   35000        NaN
#
#          date  lookingfor city
# 79 2018-06-28  Live Bands  NaN

# %%
# Instead of leaving it as NaN set it to 0, although that's not possible as event cannot have "0" gathering
df['gathering'].fillna(0, inplace = True)

# %%
# Converting date to a DateTime Format
df['date'] = pd.to_datetime(df['date'])

# %%
# Checking who all pitch artist to the user.
df.dealowner.unique()
# Out:
# array(['Shambhavi from StarClinch', 'Shalini from StarClinch',
#        'Prasanta From StarClinch', 'Nitisha from StarClinch',
#        'Abhishek from StarClinch', 'Geetika from StarClinch'],
#       dtype=object)

# %%
# Stripping From StarClinch from the names.
# Now, we only have the names.
df['dealowner'] = df['dealowner'].str.split(expand = True)[0]

# %%
# Sorting the Dataframe based on DealID
df.sort_values('dealid', ascending = True, inplace = True)

# %%
df.head()
# Out:
#    asid          created  dealid  dealowner           clientname  \
# 0   272  5/17/2018 22:02    3255  Shambhavi                 Amit
# 1   338  5/22/2018 16:43    4995    Shalini               Kavita
# 2   300  5/19/2018 20:03    5814  Shambhavi        Gautam Kapoor
# 3   268  5/17/2018 17:26    5871   Prasanta       Rajat Aggarwal
# 4   320  5/21/2018 19:19    6395    Nitisha  Ajay Kumar   dhiman
#
#                                    location        categoryname   eventname  \
# 0                Nagpur, Maharashtra, India              SINGER     charity
# 1  Andheri East, Mumbai, Maharashtra, India        ANCHOR/EMCEE   corporate
# 2                               Jim corbett           LIVE BAND     wedding
# 3             Beauty & Spa, praghati maidan        ANCHOR/EMCEE  exhibition
# 4                                Chandigarh  PHOTO/VIDEOGRAPHER     wedding
#
#                                           artisturls  \
# 0  abhigyan-das, deepak-malik, mohit-gaur, pawand...
# 1  divya-malik, saddvi-bajaj, vandana-bisht, aish...
# 2  anhad-the-band, rangreza-the-band, big-m, mera...
# 3  anchor-ekta-sharma, anchor-shina-gujral, kanis...
# 4  aj-frames, soulmate-weddings, vivah-moments, s...
#
#                                              artists  budget  gathering  \
# 0  15,90,50,15,90,53,15,70,00,00,00,00,00,00,00,0...  200000     2000.0
# 1  40,41,30,64,09,72,93,40,00,00,00,00,00,00,00,0...   85000     1000.0
# 2            33,29,25,19,72,41,44,30,00,00,00,00,000   30000      160.0
# 3  2,43,65,02,72,02,40,56,00,00,00,00,00,00,00,00...   10000     2000.0
# 4  2,39,37,22,63,29,34,12,00,00,00,00,00,00,00,00...  150000      250.0
#
#         date                    lookingfor        city
# 0 2018-06-16                           NaN         NaN
# 1 2018-11-16                           NaN       Delhi
# 2 2019-08-02                           NaN       Delhi
# 3 2018-05-28   https://starclinch.com/ilia       Delhi
# 4 2018-10-11  Harnav Bir Singh Photography  Chandigarh

# %% [markdown]
# ## Splitting the DataSet
# Split the dataset into PYR Information i.e Information that user fills in <i>Post Your Requirement</i>
#
#     Name of the Client, Type of Artist, Event Type, Venue, Date, Gathering Size & Budget
#
# & Information of artist pitched to the user by the Deal Owner.
#
#     Name of the Dealer, ID Artists Pitched & URL of Artists Pitched.
#
# Both have <i>asid</i> & <i>dealid</i> as the <b>KEY</b> to cross-check b/w data.

# %%
# PYR and Deal Features
PYR_Feat = ['asid', 'dealid', 'clientname', 'categoryname', 'eventname', 'location', 'date', 'gathering', 'budget']
deal_Feat = ['asid', 'dealid', 'dealowner', 'artists', 'artisturls']

# Spliting the Dataframe into two parts
PYR = df[PYR_Feat].copy()
deal = df[deal_Feat].copy()

# %%
PYR.head()
# Out:
#    asid  dealid           clientname        categoryname   eventname  \
# 0   272    3255                 Amit              SINGER     charity
# 1   338    4995               Kavita        ANCHOR/EMCEE   corporate
# 2   300    5814        Gautam Kapoor           LIVE BAND     wedding
# 3   268    5871       Rajat Aggarwal        ANCHOR/EMCEE  exhibition
# 4   320    6395  Ajay Kumar   dhiman  PHOTO/VIDEOGRAPHER     wedding
#
#                                    location       date  gathering  budget
# 0                Nagpur, Maharashtra, India 2018-06-16     2000.0  200000
# 1  Andheri East, Mumbai, Maharashtra, India 2018-11-16     1000.0   85000
# 2                               Jim corbett 2019-08-02      160.0   30000
# 3             Beauty & Spa, praghati maidan 2018-05-28     2000.0   10000
# 4                                Chandigarh 2018-10-11      250.0  150000

# %%
deal.head()
# Out:
#    asid  dealid  dealowner                                            artists  \
# 0   272    3255  Shambhavi  15,90,50,15,90,53,15,70,00,00,00,00,00,00,00,0...
# 1   338    4995    Shalini  40,41,30,64,09,72,93,40,00,00,00,00,00,00,00,0...
# 2   300    5814  Shambhavi            33,29,25,19,72,41,44,30,00,00,00,00,000
# 3   268    5871   Prasanta  2,43,65,02,72,02,40,56,00,00,00,00,00,00,00,00...
# 4   320    6395    Nitisha  2,39,37,22,63,29,34,12,00,00,00,00,00,00,00,00...
#
#                                           artisturls
# 0  abhigyan-das, deepak-malik, mohit-gaur, pawand...
# 1  divya-malik, saddvi-bajaj, vandana-bisht, aish...
# 2  anhad-the-band, rangreza-the-band, big-m, mera...
# 3  anchor-ekta-sharma, anchor-shina-gujral, kanis...
# 4  aj-frames, soulmate-weddings, vivah-moments, s...

# %% [markdown]
# ## Building User Similarity Metrics

# %%
# Clean the Dataset
def clean_dataset(x):
    if isinstance(x, str):
        return str.lower(x.replace(" ", "").replace("&", ",").replace("/",","))
    else:
        return ''

# %%
# Clean the dataframe using clean_dataset() function
feat = ['categoryname', 'eventname', 'location']
for f in feat:
    PYR[f] = PYR[f].apply(clean_dataset)

# %%
# Create a Soup i.e 
## A new Column that combines Category, EventName and Location
## for applying TF-IDF
def create_soup(x):
    return ''.join(x['categoryname']) + ', ' + ''.join(x['eventname']) + ', ' + ''.join(x['location'])

# %%
# Create SOUP
PYR['soup'] = PYR.apply(create_soup, axis = 1)

# %%
PYR.head()
# Out:
#    asid  dealid           clientname        categoryname   eventname  \
# 0   272    3255                 Amit              singer     charity
# 1   338    4995               Kavita        anchor,emcee   corporate
# 2   300    5814        Gautam Kapoor            liveband     wedding
# 3   268    5871       Rajat Aggarwal        anchor,emcee  exhibition
# 4   320    6395  Ajay Kumar   dhiman  photo,videographer     wedding
#
#                                location       date  gathering  budget  \
# 0              nagpur,maharashtra,india 2018-06-16     2000.0  200000
# 1  andherieast,mumbai,maharashtra,india 2018-11-16     1000.0   85000
# 2                            jimcorbett 2019-08-02      160.0   30000
# 3             beauty,spa,praghatimaidan 2018-05-28     2000.0   10000
# 4                            chandigarh 2018-10-11      250.0  150000
#
#                                                 soup
# 0          singer, charity, nagpur,maharashtra,india
# 1  anchor,emcee, corporate, andherieast,mumbai,ma...
# 2                      liveband, wedding, jimcorbett
# 3  anchor,emcee, exhibition, beauty,spa,praghatim...
# 4            photo,videographer, wedding, chandigarh

# %% [markdown]
# ### TF-IDF
# Term Frequency - Inverse Document Frequency

# %%
# Setup tfidfvectorizer with english stop words
tfidf_vect = TfidfVectorizer(stop_words="english")

# Fit the SOUP data into TfidfVectorizer to get a tfidf matrix
tfidf_mat = tfidf_vect.fit_transform(PYR['soup'].values)

# %%
# Using Tfidf matrix to get a similarity matrix
## Using linear_kernel() available in sklearn to process fast
similarity = linear_kernel(tfidf_mat, tfidf_mat)

# %%
# Mapping of Index - DealID
indices = pd.Series(PYR.index, index = PYR['dealid'])

# Function to get similar users
def getSimilar(deal_id):

    # Get 'Index' for the given DealID
    idx = indices[deal_id]
    
    # Calculate Similarity based on the 'Index', sort the score in revere order
    score = sorted(list(enumerate(similarity[idx])), key = lambda x: x[1], reverse = True)
    # Get User + TOP 5 Similar Users
    score = score[0:6]
    
    # Get 'Index' of Similar Users
    ids = [i[0] for i in score]
    
    # Return the Details of Similar Users
    return PYR.iloc[ids]

# %%
# Get Users which are Similar to User with DealID = 3255 
getSimilar(3255)
# Out:
#     asid  dealid   clientname  categoryname        eventname  \
# 0    272    3255         Amit        singer          charity
# 13   280    6480     Mahendra      liveband     privateparty
# 1    338    4995       Kavita  anchor,emcee        corporate
# 52   341    6680  amol telang      liveband  concertfestival
# 60   357    6732       Tushar        singer        corporate
# 76   396    6807       Hartaj        singer          wedding
#
#                                 location       date  gathering  budget  \
# 0               nagpur,maharashtra,india 2018-06-16     2000.0  200000
# 13               thane,maharashtra,india 2018-06-22      130.0   30000
# 1   andherieast,mumbai,maharashtra,india 2018-11-16     1000.0   85000
# 52    vashi,navimumbai,maharashtra,india 2018-09-16      200.0   60000
# 60                                indore 2018-07-29      250.0  200000
# 76                                 delhi 2018-10-28      300.0  200000
#
#                                                  soup
# 0           singer, charity, nagpur,maharashtra,india
# 13    liveband, privateparty, thane,maharashtra,india
# 1   anchor,emcee, corporate, andherieast,mumbai,ma...
# 52  liveband, concertfestival, vashi,navimumbai,ma...
# 60                          singer, corporate, indore
# 76                             singer, wedding, delhi

# %%
# Get Users which are Similar to User with DealID = 5814 
getSimilar(5814)
# Out:
#     asid  dealid     clientname categoryname     eventname  \
# 2    300    5814  Gautam Kapoor     liveband       wedding
# 17   296    6497      G.l verma     liveband       wedding
# 22   299    6536     Dev khanna     liveband       wedding
# 77   385    6808     Saisandeep     liveband       wedding
# 14   294    6490          Olive     liveband       wedding
# 80   394    6819        yashima     liveband  privateparty
#
#                    location       date  gathering  budget  \
# 2                jimcorbett 2019-08-02      160.0   30000
# 17                    jammu 2018-10-18     3000.0   80000
# 22                 jhunjhnu 2018-05-28        0.0   25000
# 77               vijayawada 2018-06-23     1200.0  100000
# 14  chennai,tamilnadu,india 2018-11-25      500.0   30000
# 80                 newdelhi 2018-06-17      350.0  200000
#
#                                           soup
# 2                liveband, wedding, jimcorbett
# 17                    liveband, wedding, jammu
# 22                 liveband, wedding, jhunjhnu
# 77               liveband, wedding, vijayawada
# 14  liveband, wedding, chennai,tamilnadu,india
# 80            liveband, privateparty, newdelhi

# %% [markdown]
# Model is not 100% Accurate but given the amount of data it works well.
#
# User with similar requirements are appearing to be closer to each other.

# %% [markdown]
# ## END
